# %%
# %%capture
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Developer/trading/CryptoTrader/src

# %pip install pyts

# %%
import sys
sys.path.append('/content/drive/MyDrive/Developer/trading/CryptoTrader/src')
sys.path.append('/content/drive/MyDrive/Developer/trading/CryptoTrader/src/dataset')

# %%
from config.config import Config
from dataset.features import FeatureEngineering
config = Config()
config.data_dir = '../data'
fe = FeatureEngineering(config=config)
fe.make()
# Out:
#                       Datetime  tic      Open      High       Low     Close  \
# 0      2021-01-16 14:59:59.999  ETH  0.179017  0.171161  0.193437  0.222160
# 361781 2021-01-16 14:59:59.999  XLM  0.162346  0.148557  0.163741  0.165034
# 40530  2021-01-16 14:59:59.999  ADA  0.025840  0.009617  0.030400  0.026126
# 20268  2021-01-16 14:59:59.999  BTC  0.204488  0.213656  0.223604  0.218569
# 341519 2021-01-16 14:59:59.999  ETC  0.076523  0.065600  0.085448  0.085576
#
#           Volume  ABER_ZG_26_30  ABER_SG_26_30  ABER_XG_26_30  ...  \
# 0       0.281188       0.923279       0.948240       0.898318  ...
# 361781  0.033935       0.997264       1.028134       0.966394  ...
# 40530   0.059931       0.978936       1.007463       0.950408  ...
# 20268   0.106233       1.007187       1.030570       0.983804  ...
# 341519  0.048005       0.996476       1.019019       0.973932  ...
#
#         TSI_31_55_13  TSIs_31_55_13  VIDYA_179  fear_greed  label  change  \
# ...
